# %%
import wfdb

# %%
dbs = wfdb.io.get_record_list('ltmm')

# %%
t_min = 60
fps = 200
t_frame = t_min * 60 * fps
rec = wfdb.io.rdrecord(dbs[0], sampfrom=0, sampto=t_frame)

# %%
rec

# %%
rec.sig_name
# Out:
# ['v-acceleration',
#  'ml-acceleration',
#  'ap-acceleration',
#  '/s 0 0 -1124 3453 0 yaw-velocity',
#  '/s 0 0 -883 -9724 0 pitch-velocity',
#  '/s 0 0 634 -26911 0 roll-velocity']

# %%
signal = rec.p_signal

# %%
print(signal.shape)
# Out:
# (720000, 6)

# %%
import matplotlib.pyplot as plt
for i in range(6):
    plt.plot(signal[:,i])
plt.show()

# %%
def minutes2frames(t_minutes, fps=100):
    return t_minutes*fps*60

def grab_window(dbs, irec = 0, fstart = 0, fclose = 2500):
    rec = wfdb.io.rdrecord( dbs[irec], 
                            sampfrom=fstart, 
                            sampto=fclose    )
    return rec.p_signal, rec.sig_name

def plot_window(dbs, irec = 0, fstart = 0, fclose = 2500,
               acc = True, rot = True):
    clip, head = grab_window(dbs, irec = irec, 
                             fstart = fstart, fclose = fclose )
    c1 = "blue"
    c2 = "green"
    if acc and rot:
        fig, ax1 = plt.subplots()
        c1 = "blue"
        ax1.set_xlabel('time (frames)')
        ax1.set_ylabel('accelerations', color = c1)
        for i in range(3):
            ax1.plot(clip[:,i], label=head[i], color = c1)
        
        ax2 = ax1.twinx()
        ax2.set_ylabel("rotations", color = c2)
        for i in range(3):
            ax2.plot(clip[:,i+3], label=head[i+3], color = c2)

        fig.tight_layout()
    if acc and not rot:
        plt.xlabel('time (frames)')
        plt.ylabel('accelerations', color = c1)
        for i in range(3):
            plt.plot(clip[:,i], label=head[i], color = c1)
            
    if rot and not acc:
        plt.xlabel('time (frames)')
        plt.ylabel('rotations', color = c2)
        for i in range(3):
            plt.plot(clip[:,i+3], label=head[i+3], color = c2)
    
#     plt.legend()
    plt.show()
    plt.clf()

clip, head = grab_window(dbs)

# %%
clip.shape
# Out:
# (2500, 6)

# %%
plt.plot(clip)
# Out:
# [<matplotlib.lines.Line2D at 0x7f931578a8d0>,
#  <matplotlib.lines.Line2D at 0x7f931578ab10>,
#  <matplotlib.lines.Line2D at 0x7f931578acd0>,
#  <matplotlib.lines.Line2D at 0x7f931578ae90>,
#  <matplotlib.lines.Line2D at 0x7f9315795050>,
#  <matplotlib.lines.Line2D at 0x7f9315795250>]

# %%
fstart = 10000
ftotal = 2500
fclose = fstart + ftotal
plot_window(dbs, fstart = fstart, fclose = fclose )

# %%
from tensorflow.keras.models import model_from_json
import h5py
import os
# serialize model to JSON
def save_model(model):
    model_json = model.to_json()
    with open("model_100.json", "w") as json_file:
        json_file.write(model_json)
    # serialize weights to HDF5
    model.save_weights("model_100.h5")
    print("Saved model to disk")
    
def load_model(fstr = "model"):
    loc = os.path.abspath("/home/apatch/Documents/Insight/wobblewatch/models")
    fjson = "%s/%s.json" % (loc, fstr)
    fh5   = "%s/%s.h5" % (loc, fstr)
    json_file = open(fjson, 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    loaded_model = model_from_json(loaded_model_json)
    # load weights into new model
    loaded_model.load_weights(fh5)
    print("Loaded model from disk")
    return loaded_model

model = load_model()
# Out:
# Loaded model from disk

# %%
df, header = grab_window(dbs, irec = 0, fstart = 0, fclose = 256)

# %%
df.shape
# Out:
# (256, 6)

# %%
from scipy import signal
x = np.arange(0,len(df),1)
df2 = signal.resample(df,2*len(df))
print(df.shape, df2.shape)
x2 = np.arange(0,len(df),0.5)
print(x.shape, x2.shape)
plt.plot(x, df[:,3], label="regular")
plt.plot(x2, df2[:,3], label="resample")
plt.xlim([0,30])
plt.legend()
plt.show()
df2
# Out:
# (256, 6) (512, 6)
# (256,) (512,)
# array([[-0.02430932, -0.00709566, -1.05035309,  0.19197293,  2.66644846,
#          0.00706453],
#        [-0.02239338, -0.00691597, -1.05367   ,  0.19138965,  2.05714311,
#         -0.00439768],
#        [-0.0214494 , -0.00709566, -1.05905317,  0.27424704,  0.83943748,
#         -0.01412905],
#        ...,
#        [-0.02380142, -0.01067618, -1.0395495 ,  0.01346675, -0.86462658,
#          0.0144137 ],
#        [-0.02430932, -0.00993393, -1.04165302,  0.06170558, -0.2045688 ,
#          0.02119358],
#        [-0.0250431 , -0.00818669, -1.04657842,  0.16741755,  1.59773113,
#          0.01730309]])

# %%
import numpy as np
def grab_windows(dbs, irec = 0, start = 0, end = 60, 
                 fps = 100, stride = 200):
    windows = []
    n_frames = (end - start)*fps
    n_strides = int(n_frames / stride)
    for i in range(n_strides):
        _fs = start + i*stride
        _fc = _fs + 256
        _df, _head = grab_window(dbs, irec = irec, fstart = _fs, fclose = _fc)
        windows.append(_df)
    return np.array(windows)
    
def evaluate_windows(dbs, irec = 0, start = 0, end = 60, fps = 200, stride = 256):
    _windows = grab_windows(dbs, irec = irec, 
                            start = start, end = end, 
                            fps = fps, stride = stride)
    results = model.predict(_windows)
    return np.argmax(results, axis=1)

# %%
len(windows)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-5c299511e651> in <module>
# ----> 1 len(windows)
#
# NameError: name 'windows' is not defined

# %%
results = model.predict(windows)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-39065353c4f2> in <module>
# ----> 1 results = model.predict(windows)
#
# NameError: name 'windows' is not defined

# %%
results_max = np.argmax(results, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-8d2a9150466e> in <module>
# ----> 1 results_max = np.argmax(results, axis=1)
#
# NameError: name 'results' is not defined

# %%
plt.plot(results_max)

# %%
_res = evaluate_windows(dbs, irec = 50, start = 0, end = 6*3600)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-face34818769> in <module>
# ----> 1 _res = evaluate_windows(dbs, irec = 50, start = 0, end = 6*3600)
#
# <ipython-input-13-bc30c99f1425> in evaluate_windows(dbs, irec, start, end, fps, stride)
#      15     _windows = grab_windows(dbs, irec = irec,
#      16                             start = start, end = end,
# ---> 17                             fps = fps, stride = stride)
#      18     results = model.predict(_windows)
#      19     return np.argmax(results, axis=1)
#
# <ipython-input-13-bc30c99f1425> in grab_windows(dbs, irec, start, end, fps, stride)
#       8         _fs = start + i*stride
#       9         _fc = _fs + 256
# ---> 10         _df, _head = grab_window(dbs, irec = irec, fstart = _fs, fclose = _fc)
#      11         windows.append(_df)
#      12     return np.array(windows)
#
# <ipython-input-8-71e2f3b7565b> in grab_window(dbs, irec, fstart, fclose)
#       5     rec = wfdb.io.rdrecord( dbs[irec],
#       6                             sampfrom=fstart,
# ----> 7                             sampto=fclose    )
#       8     return rec.p_signal, rec.sig_name
#       9
#
# ~/anaconda3/lib/python3.7/site-packages/wfdb/io/record.py in rdrecord(record_name, sampfrom, sampto, channels, physical, pb_dir, m2s, smooth_frames, ignore_skew, return_res, force_channels, channel_names, warn_empty)
#    1152
#    1153     # Read the header fields
# -> 1154     record = rdheader(record_name, pb_dir=pb_dir, rd_segments=False)
#    1155
#    1156     # Set defaults for sampto and channels input variables
#
# ~/anaconda3/lib/python3.7/site-packages/wfdb/io/record.py in rdheader(record_name, pb_dir, rd_segments)
#    1002         if len(header_lines)>1:
#    1003             # Read the fields from the signal lines
# -> 1004             signal_fields = _header._parse_signal_lines(header_lines[1:])
#    1005             # Set the object's signal fields
#    1006             for field in signal_fields:
#
# ~/anaconda3/lib/python3.7/site-packages/wfdb/io/_header.py in _parse_signal_lines(signal_lines)
#     807             # that different channels can be present or missing.
#     808             if signal_fields[field][ch] == '':
# --> 809                 signal_fields[field][ch] = SIGNAL_SPECS.loc[field, 'read_default']
#     810
#     811                 # Special case: missing baseline defaults to ADCzero if present
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1754         if type(key) is tuple:
#    1755             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
# -> 1756             if self._is_scalar_access(key):
#    1757                 try:
#    1758                     return self._getitem_scalar(key)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _is_scalar_access(self, key)
#    1840         # a) avoid getting things via sections and (to minimize dtype changes)
#    1841         # b) provide a performant path
# -> 1842         if len(key) != self.ndim:
#    1843             return False
#    1844
#
# pandas/_libs/indexing.pyx in pandas._libs.indexing._NDFrameIndexerBase.ndim.__get__()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in ndim(self)
#     513         return [self._get_axis(a) for a in self._AXIS_ORDERS]
#     514
# --> 515     @property
#     516     def ndim(self) -> int:
#     517         """
#
# KeyboardInterrupt:

# %%
plt.plot(_res)
plt.yticks([0,1,2])
plt.show()

# %%
import matplotlib.pyplot as plt

def grab_hours(dbs, irec = 0, hour_start = 0, hour_end = 24):
    results = []
    for i in range(hour_start, hour_end):
        t_start = i * 60*60
        t_end = (i+1) * 60*60
        print("Hour ", i+1)
        results.extend(evaluate_windows(dbs, irec = irec, 
                                        start = t_start, end = t_end))
    return results

# %%
t = np.arange(0,len(results),1) / 100
plt.plot(t,results)
plt.title("Physionet ADL Subject 50: Falling subject")
plt.ylabel("stumble event")
plt.xlabel("time (min)")
# Out:
# Text(0.5, 0, 'time (min)')

# %%
results = grab_hours(dbs, irec=50, hour_start=24, hour_end=36)
plt.plot(results)
# Out:
# Hour  25
# Hour  26
# Hour  27
# Hour  28
# Hour  29
# Hour  30
# Hour  31
# Hour  32
# Hour  33
# Hour  34
# Hour  35
# Hour  36

# %%
dbs[1]

# %%
results = grab_hours(dbs, irec=9, hour_start=0, hour_end=24)
plt.plot(results)

# %%
plot_window(dbs, irec = 25, fstart = 0, fclose = 2*3600*100,
            acc = True, rot = True)

# %%
print(dbs[45])
results = grab_hours(dbs, irec=25, hour_start=0, hour_end=24)
plt.plot(results)
